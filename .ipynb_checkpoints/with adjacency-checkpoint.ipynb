# %%
import pandas as pd 
import datetime
data= pd.read_csv('C:\\Users\\raosa\\Dropbox\\data\\combined\\9.csv')

# %%
final = pd.read_csv('final2.csv')

# %%
for i in range(0,len(data)):
    data['timestamp'][i] = datetime.datetime.fromtimestamp(int(str(data['timestamp'][i]),16))
    data['value'][i] = int(data['value'][i],16)/1000000000000000

# %%
nanmin = []
nanmax = []
nanmedian=[]
nanmean = []
nanstd = []
nanvar = []
corrcoef = []
pct_25 = []
pct_50 = []
pct_75 = []
pct_100 = []

# %%
import networkx as nx

for i in range(0,len(data)-1):
    G = data

    G=G.drop(['gas','gasprice','input','gas_used','miner','number'], axis=1)
    G['timestamp'] = pd.to_datetime(G['timestamp'])
    final['Date'] = pd.to_datetime(final['Date'])
    G = G[(G['timestamp'] > final['Date'][i]) & (G['timestamp'] < final['Date'][i+1])]
    G=G.drop(['timestamp'], axis=1)
    list1 = G['from']
    list2 = G['to']
    nodes = list(set(list1 + list2))

    G1 = nx.Graph()
    G1.add_nodes_from(nodes)
    G1.add_edges_from(list(zip(list1,list2)),weight=G['value'])
    if (len(G1)!=0):
        matrix = nx.adjacency_spectrum(G1, weight='value')
        nanmin.append(np.nanmin(matrix))
        date.append(final['Date'][i+1])
        nanmax.append(np.nanmax(matrix))
        nanmedian.append(np.nanmedian(matrix))
        nanmean.append(np.nanmean(matrix))
        nanstd.append(np.nanstd(matrix))
        nanvar.append(np.nanvar(matrix))
        corrcoef.append(np.corrcoef(matrix))
        pct_25.append(np.percentile(matrix,25))
        pct_50.append(np.percentile(matrix,50))
        pct_75.append(np.percentile(matrix,75))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-fea8ebf83edd> in <module>()
#       7     G['timestamp'] = pd.to_datetime(G['timestamp'])
#       8     final['Date'] = pd.to_datetime(final['Date'])
# ----> 9     G = G[(G['timestamp'] > final['Date'][i]) & (G['timestamp'] < final['Date'][i+1])]
#      10     G=G.drop(['timestamp'], axis=1)
#      11     list1 = G['from']
#
# C:\Users\raosa\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# C:\Users\raosa\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2475         try:
#    2476             return self._engine.get_value(s, k,
# -> 2477                                           tz=getattr(series.dtype, 'tz', None))
#    2478         except KeyError as e1:
#    2479             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value (pandas\_libs\index.c:4404)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value (pandas\_libs\index.c:4087)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas\_libs\hashtable.c:14031)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas\_libs\hashtable.c:13975)()
#
# KeyError: 21184

# %%
# Out:
# 0

# %%
test = pd.DataFrame({'nanmin':nanmin,'Date':date,'nanmax':nanmax,'nanmedian':nanmedian,'nanmean':nanmean,
                     'nanstd':nanstd,'nanvar':nanvar,'corrcoef':corrcoef,'pct_25':pct_25,'pct_50':pct_50,'pct_75':pct_75,
                     'pct_100':pct_100})

# %%
test1 = pd.merge(test, final, on='Date')

# %%
test1['nanmin'] = test1['nanmin'].real 
test1['nanmax'] = test1['nanmax'].real
test1['nanmedian'] = test1['nanmedian'].real
test1['nanmean'] = test1['nanmean'].real
test1['nanstd'] = test1['nanstd'].real
test1['nanstd'] = test1['nanstd'].real
test1['nanvar'] = test1['nanvar'].real
test1['corrcoef'] = test1['corrcoef'].real
test1['pct_25'] = test1['pct_25'].real
test1['pct_50'] = test1['pct_50'].real
test1['pct_75'] = test1['pct_75'].real
test1['pct_100'] = test1['pct_100'].real

# %%
test1.to_csv('final102.csv',index=False)

# %%
# Out:
# array([ -7.35215771e+00 +0.00000000e+00j,
#          7.35215771e+00 +0.00000000e+00j,
#         -5.06409290e+00 +0.00000000e+00j,
#          5.06409290e+00 +0.00000000e+00j,
#         -4.16542600e+00 +0.00000000e+00j,
#         -7.69242213e-18 +0.00000000e+00j,
#         -1.45747886e-18 +1.88268976e-18j,
#         -1.45747886e-18 -1.88268976e-18j,
#         -9.22068308e-32 +3.82352882e-32j,
#         -9.22068308e-32 -3.82352882e-32j,
#          6.24023193e-32 +7.02773540e-32j,
#          6.24023193e-32 -7.02773540e-32j,
#         -8.33993725e-32 +0.00000000e+00j,
#         -2.58119808e-32 +5.13421122e-32j,
#         -2.58119808e-32 -5.13421122e-32j,
#         -4.44061562e-32 +0.00000000e+00j,
#          4.02106734e-32 +0.00000000e+00j,
#          3.32164528e-32 +2.01824135e-32j,
#          3.32164528e-32 -2.01824135e-32j,
#         -3.16439162e-32 +0.00000000e+00j,
#          1.66936896e-32 +2.13835990e-32j,
#          1.66936896e-32 -2.13835990e-32j,
#         -1.80148538e-32 +1.41701976e-32j,
#         -1.80148538e-32 -1.41701976e-32j,
#         -7.03086437e-33 +1.56640626e-32j,
#         -7.03086437e-33 -1.56640626e-32j,
#          1.53251890e-32 +0.00000000e+00j,
#          1.78648643e-32 +0.00000000e+00j,
#         -5.12961640e-33 +0.00000000e+00j,
#          9.07848314e-33 +0.00000000e+00j,
#          3.22501531e-49 +0.00000000e+00j,
#         -1.92933080e-48 +0.00000000e+00j,
#          4.67327614e-51 +1.16139199e-49j,
#          4.67327614e-51 -1.16139199e-49j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,
#          0.00000000e+00 +0.00000000e+00j,   0.00000000e+00 +0.00000000e+00j])

# %%
G = data
G = G[(G['timestamp'] > final['Date'][200]) & (G['timestamp'] < final['Date'][201])]
G=G.drop(['timestamp'], axis=1)
list1 = G['from']
list2 = G['to']
nodes = list(set(list1 + list2))

G1 = nx.Graph()
G1.add_nodes_from(nodes)
G1.add_edges_from(list(zip(list1,list2)),weight=G['value'])

matrix = nx.adjacency_spectrum(G1, weight='value')

# minimum value without nulls 
np.nanmin(matrix)
# maximum value without nulls 
np.nanmax(matrix)
# median 
np.nanmedian(matrix)
# average 
np.nanmean(matrix)
# std 
np.nanstd(matrix)
# var 
np.nanvar(matrix)
# corrcoef 
np.corrcoef(matrix)
# 25th percentile 
np.percentile(matrix,25)
# 50th percentile 
np.percentile(matrix,50)
# 75th percentile 
np.percentile(matrix,75)
# 100th percentile 
np.percentile(matrix,100)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-262-801cfaf84734> in <module>()
#      10 G1.add_edges_from(list(zip(list1,list2)),weight=G['value'])
#      11
# ---> 12 matrix = nx.adjacency_spectrum(G1, weight='value')
#      13
#      14 # minimum value without nulls
#
# C:\Users\raosa\Anaconda3\lib\site-packages\networkx\linalg\spectrum.py in adjacency_spectrum(G, weight)
#      74     """
#      75     from scipy.linalg import eigvals
# ---> 76     return eigvals(nx.adjacency_matrix(G, weight=weight).todense())
#      77
#      78
#
# C:\Users\raosa\Anaconda3\lib\site-packages\networkx\linalg\graphmatrix.py in adjacency_matrix(G, nodelist, weight)
#     160     to_dict_of_dicts
#     161     """
# --> 162     return nx.to_scipy_sparse_matrix(G, nodelist=nodelist, weight=weight)
#     163
#     164
#
# C:\Users\raosa\Anaconda3\lib\site-packages\networkx\convert_matrix.py in to_scipy_sparse_matrix(G, nodelist, dtype, weight, format)
#     762     nlen = len(nodelist)
#     763     if nlen == 0:
# --> 764         raise nx.NetworkXError("Graph has no nodes or edges")
#     765
#     766     if len(nodelist) != len(set(nodelist)):
#
# NetworkXError: Graph has no nodes or edges

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-261-ec78e58a4252> in <module>()
# ----> 1 from keras.layers import Activation, Dense
#
# ModuleNotFoundError: No module named 'keras'
